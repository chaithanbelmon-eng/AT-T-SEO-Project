# %%
import pandas as pd

file_path = '/content/drive/My Drive/Colab Notebooks/Internet - GSC Data via seoClarity - August 2025 YoY.csv'
try:
  df = pd.read_csv(file_path)
  display(df.head())
except FileNotFoundError:
  print(f"Error: File not found at {file_path}")
except Exception as e:
  print(f"An error occurred: {e}")
# Out:
#                      Keyword  \
# 0            spectrum vs att
# 1       ebt internet service
# 2  free wifi from government
# 3  how fast is at&t internet
# 4                     at&t #
#
#                                                  URL  \
# 0  https://www.att.com/internet/fiber/att-vs-spec...
# 1               https://www.att.com/internet/access/
# 2               https://www.att.com/internet/access/
# 3  https://www.att.com/internet/internet-service-...
# 4                      https://www.att.com/internet/
#
#    Impressions Aug 2024 - Aug 2024  Impressions Aug 2025 - Aug 2025  \
# 0                              190                              222
# 1                                2                               16
# 2                               18                               52
# 3                                0                               18
# 4                                0                                5
#
# ...

# %%
total_impressions_aug_2024_branded = df_filtered_regex['Impressions Aug 2024 - Aug 2024'].sum()
print(f"Total Impressions for branded keywords in Aug 2024: {total_impressions_aug_2024_branded}")
# Out:
# Total Impressions for branded keywords in Aug 2024: 11172837

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def compare_metric_and_visualize(df, metric_column_2024, metric_column_2025, metric_name):
  """
  Compares a specific metric between two years and generates a bar chart.

  Args:
    df (pd.DataFrame): The input DataFrame.
    metric_column_2024 (str): The name of the column for the 2024 metric.
    metric_column_2025 (str): The name of the column for the 2025 metric.
    metric_name (str): The name of the metric for labeling the plot.
  """
  total_2024 = df[metric_column_2024].sum()
  total_2025 = df[metric_column_2025].sum()

  plt.figure(figsize=(8, 5))
  sns.barplot(x=['Year 2024', 'Year 2025'], y=[total_2024, total_2025])
  plt.ylabel(f'Total {metric_name}')
  plt.title(f'Comparison of Total {metric_name} (Year 2024 vs Year 2025)')
  plt.show()

# Example usage (assuming 'df_filtered_regex' is your filtered DataFrame)
# compare_metric_and_visualize(df_filtered_regex, 'Impressions Aug 2024 - Aug 2024', 'Impressions Aug 2025 - Aug 2025', 'Impressions')

# %% [markdown]
# ## Visualize key trends
#
# ### Subtask:
# Create visualizations (e.g., bar charts or line plots) to show the comparison of key SEO metrics between 2024 and 2025.

# %% [markdown]
# **Reasoning**:
# Create bar plots to visualize the comparison of key SEO metrics between 2024 and 2025.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Metrics and their values for 2024 and 2025
metrics = ['Impressions', 'Clicks', 'CTR', 'Average Position']
values_2024 = [total_impressions_2024, total_clicks_2024, average_ctr_2024, average_position_2024]
values_2025 = [total_impressions_2025, total_clicks_2025, average_ctr_2025, average_position_2025]

# Create bar plot for Impressions
plt.figure(figsize=(8, 5))
sns.barplot(x=['Aug 2024', 'Aug 2025'], y=[values_2024[0], values_2025[0]])
plt.ylabel('Total Impressions')
plt.title('Comparison of Total Impressions (Aug 2024 vs Aug 2025)')
plt.show()

# Create bar plot for Clicks
plt.figure(figsize=(8, 5))
sns.barplot(x=['Aug 2024', 'Aug 2025'], y=[values_2024[1], values_2025[1]])
plt.ylabel('Total Clicks')
plt.title('Comparison of Total Clicks (Aug 2024 vs Aug 2025)')
plt.show()

# Create bar plot for CTR
plt.figure(figsize=(8, 5))
sns.barplot(x=['Aug 2024', 'Aug 2025'], y=[values_2024[2], values_2025[2]])
plt.ylabel('Average CTR')
plt.title('Comparison of Average CTR (Aug 2024 vs Aug 2025)')
plt.show()

# Create bar plot for Average Position
plt.figure(figsize=(8, 5))
sns.barplot(x=['Aug 2024', 'Aug 2025'], y=[values_2024[3], values_2025[3]])
plt.ylabel('Average Position (Lower is Better)')
plt.title('Comparison of Average Position (Aug 2024 vs Aug 2025)')
plt.show()

# %% [markdown]
# ## Summarize seo insights
#
# ### Subtask:
# Provide a summary of the key findings from the analysis, highlighting significant changes and insights from an SEO point of view.

# %% [markdown]
# **Reasoning**:
# Synthesize the findings from the previous steps to create a comprehensive summary of the key SEO insights.

# %%
print("## SEO Analysis Summary for Branded Keywords on /internet/ URLs (Aug 2024 vs Aug 2025)")
print("\n**Overall Performance:**")
print(f"- Total Impressions decreased by {impressions_percentage_change:.2f}% ({impressions_absolute_change:,.0f} fewer impressions) year-over-year.")
print(f"- Total Clicks also decreased by {clicks_percentage_change:.2f}% ({clicks_absolute_change:,.0f} fewer clicks) year-over-year.")
print(f"- Average CTR significantly increased by {ctr_percentage_change:.2f}% (+{ctr_absolute_change:.4f}) year-over-year.")
print(f"- Average Position slightly worsened by {average_position_percentage_change:.2f}% (+{average_position_absolute_change:.2f}) year-over-year.")

print("\n**Interpretation:**")
print("The decrease in impressions and clicks suggests either reduced search demand for branded 'internet' keywords, increased competition, or potential algorithm shifts impacting visibility. However, the notable increase in CTR indicates that when users *do* see the results for these branded keywords, they are more likely to click. This could be due to improved snippet optimization, more compelling messaging, or a stronger brand association for users who are searching.")
print("The slight decline in average position suggests that on average, branded internet keywords are ranking slightly lower in 2025 compared to 2024. This could be a contributing factor to the decrease in impressions and clicks.")

print("\n**Top Performing Keywords:**")
print("The top performing keywords in both years highlight the importance of core branded terms like 'att internet' and 'att fiber'. Shifts in the top keywords for clicks (from 'att internet' in 2024 to 'att fiber' in 2025) might indicate changing user interest or promotional focus towards fiber services.")

print("\n**Keywords with Significant Changes:**")
print("Analyzing keywords with significant changes revealed specific opportunities and areas of concern. Keywords with large positive changes in impressions or clicks could be growing in search volume or benefiting from improved relevance and ranking. Conversely, keywords with significant negative changes require further investigation to understand the root causes, which could range from technical issues to content decay or increased competitor activity.")
print("Keywords with significant positive CTR changes, even with decreasing impressions, are effectively capturing user attention when they appear. Identifying what makes these snippets compelling could inform optimization strategies for other keywords.")
print("Keywords with significant positive average position changes (worse ranking) are clear candidates for SEO efforts to improve their search visibility and recover lost impressions and clicks.")

print("\n**SEO Recommendations:**")
print("- Investigate the reasons behind the overall decrease in branded impressions and clicks. This could involve analyzing search trend data, competitor activity, and recent website or algorithm changes.")
print("- Leverage the insights from keywords with high and improving CTRs to optimize meta descriptions and titles for other branded internet terms.")
print("- Prioritize improving the average position for keywords that have seen a significant decline in ranking, as this directly impacts visibility and traffic.")
print("- Monitor the performance of top keywords closely and adapt strategies based on changing user search behavior, particularly the apparent increased interest in 'att fiber'.")
# Out:
# ## SEO Analysis Summary for Branded Keywords on /internet/ URLs (Aug 2024 vs Aug 2025)
#
# **Overall Performance:**
# - Total Impressions decreased by -7.70% (-859,959 fewer impressions) year-over-year.
# - Total Clicks also decreased by -12.20% (-48,279 fewer clicks) year-over-year.
# - Average CTR significantly increased by 19.00% (+0.0474) year-over-year.
# - Average Position slightly worsened by 4.62% (+0.12) year-over-year.
#
# **Interpretation:**
# The decrease in impressions and clicks suggests either reduced search demand for branded 'internet' keywords, increased competition, or potential algorithm shifts impacting visibility. However, the notable increase in CTR indicates that when users *do* see the results for these branded keywords, they are more likely to click. This could be due to improved snippet optimization, more compelling messaging, or a stronger brand association for users who are searching.
# ...

# %%
# !ls "/content/drive/My Drive/Colab Notebooks/"
# Out:
# 'AT&T Project.ipynb'
# 'Internet - GSC Data via seoClarity - August 2025 YoY.csv'
# 'Internet - Rankings via seoClarity - August 2025 YoY.csv'
# 'Total KW Rankings - August 2025.png'
# 'Wireless - GSC Data via seoClarity - August 2025 YoY.csv'

# %% [markdown]
# `/content/drive/My Drive/Colab Notebooks/Internet - GSC Data via seoClarity - August 2025 YoY.csv`

# %% [markdown]
# # Task
# Filter the DataFrame loaded from "/content/drive/My Drive/ColabNotebooks/Internet - GSC Data via seoClarity - August 2025 YoY.csv" to include only rows where the 'URL' column starts with 'https://www.att.com/internet/' and the 'Keyword' column matches the regex pattern `(^att)|((a|s|i)(t|r)&t)|(at and t)|(att\.com)|(at&t.com)|(at t)|(at (&|\$) t)|(at &t)|(a t a(m|n)d t)|(at& t)|(atnt)|(atyt)|(at\$t)|(at@t)|(atandt)|(my arr)|(at t)|(at (&|y) t)|(at&t)|(at and t)|(att.com)|(at&t\.com)|(at t)|(at & t)|(atnt)|(atyt)|(at@t)|(atandt)|(at &t)|(a t and t)|(at& t)|(firstnet)|(u( ?|\-)verse)|(hr ?one ?stop)|(myworklife)|(nfsd)|(atat)|(direct+v)|(direc tv)|(direct ?tv)|(a t)|(a t (&|y) t)|(a t &t)|(a t t)|(a t&t)|(a tt)|(a&at)|(a&t)|(a&tt)|(art&t)|(at 7 t)|(at abd t)|(at an t)|(at and)|(at and at)|(at andt)|(at ant)|(at ant t)|(at e t)|(at n t)|(at nt)|(at snd t)|(at%t)|(at&)|(at&a)|(at&at)|(at&r)|(at&y)|(at\*t)|(at.t)|(at/t)|(at\^t)|(at\+t)|(at7t)|(atand)|(atand t)|(atand t)|(atant)|(atat)|(direct tv)|(hr access)|(hrone stop)|(my work life)|(my ?at)|(my atat)|(nfsd)|(sbcglobal)|(smart ?home ?manager)|(my\.?att)|(^t$)|(^at$)|(m(y|t) ?(a|s)tt)|(.* att .*)|(.* att$)|(active ?armou?r)|(www\.att)|(bell ?south)|(/att)|(amigo.*)|(t&t)|(.*\.att)|(aia)|(internet air)|(.*att bill)|(all ?fi)|(all\-fi)|(att\-mail)|(protect advantage)|(t and t)|(atyy)|(.*@att)|(pay ?att)|(at\$)|(cingular)`.

# %% [markdown]
# ## Filter by url
#
# ### Subtask:
# Filter the DataFrame to include only rows where the 'URL' column starts with 'https://www.att.com/internet/'.

# %% [markdown]
# **Reasoning**:
# Filter the DataFrame based on the 'URL' column starting with the specified string and store the result in a new DataFrame.

# %%
df_filtered_url = df[df['URL'].str.startswith('https://www.att.com/internet/')]
display(df_filtered_url.head())
# Out:
#                      Keyword  \
# 0            spectrum vs att
# 1       ebt internet service
# 2  free wifi from government
# 3  how fast is at&t internet
# 4                     at&t #
#
#                                                  URL  \
# 0  https://www.att.com/internet/fiber/att-vs-spec...
# 1               https://www.att.com/internet/access/
# 2               https://www.att.com/internet/access/
# 3  https://www.att.com/internet/internet-service-...
# 4                      https://www.att.com/internet/
#
#    Impressions Aug 2024 - Aug 2024  Impressions Aug 2025 - Aug 2025  \
# 0                              190                              222
# 1                                2                               16
# 2                               18                               52
# 3                                0                               18
# 4                                0                                5
#
# ...

# %% [markdown]
# ## Filter by regex
#
# ### Subtask:
# Use the provided regex pattern to further filter the DataFrame, likely based on the 'Keyword' column, to distinguish between branded and non-branded keywords.

# %% [markdown]
# **Reasoning**:
# Define the regex pattern and filter the DataFrame based on the 'Keyword' column using the regex pattern to identify branded keywords.

# %%
import re

regex_pattern = r"(^att)|((a|s|i)(t|r)&t)|(at and t)|(att\.com)|(at&t.com)|(at t)|(at (&|\$) t)|(at &t)|(a t a(m|n)d t)|(at& t)|(atnt)|(atyt)|(at\$t)|(at@t)|(atandt)|(my arr)|(at t)|(at (&|y) t)|(at&t)|(at and t)|(att.com)|(at&t\.com)|(at t)|(at & t)|(atnt)|(atyt)|(at@t)|(atandt)|(at &t)|(a t and t)|(at& t)|(firstnet)|(u( ?|\-)verse)|(hr ?one ?stop)|(myworklife)|(nfsd)|(atat)|(direct+v)|(direc tv)|(direct ?tv)|(a t)|(a t (&|y) t)|(a t &t)|(a t t)|(a t&t)|(a tt)|(a&at)|(a&t)|(a&tt)|(art&t)|(at 7 t)|(at abd t)|(at an t)|(at and)|(at and at)|(at andt)|(at ant)|(at ant t)|(at e t)|(at n t)|(at nt)|(at snd t)|(at%t)|(at&)|(at&a)|(at&at)|(at&r)|(at&y)|(at\*t)|(at.t)|(at/t)|(at\^t)|(at\+t)|(at7t)|(atand)|(atand t)|(atand t)|(atant)|(atat)|(direct tv)|(hr access)|(hrone stop)|(my work life)|(my ?at)|(my atat)|(nfsd)|(sbcglobal)|(smart ?home ?manager)|(my\.?att)|(^t$)|(^at$)|(m(y|t) ?(a|s)tt)|(.* att .*)|(.* att$)|(active ?armou?r)|(www\.att)|(bell ?south)|(/att)|(amigo.*)|(t&t)|(.*\.att)|(aia)|(internet air)|(.*att bill)|(all ?fi)|(all\-fi)|(att\-mail)|(protect advantage)|(t and t)|(atyy)|(.*@att)|(pay ?att)|(at\$)|(cingular)"
df_filtered_regex = df_filtered_url[df_filtered_url['Keyword'].str.contains(regex_pattern, flags=re.IGNORECASE, na=False)]
display(df_filtered_regex.head())
# Out:
# /tmp/ipython-input-3127493984.py:4: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_filtered_regex = df_filtered_url[df_filtered_url['Keyword'].str.contains(regex_pattern, flags=re.IGNORECASE, na=False)]
#                      Keyword  \
# 0            spectrum vs att
# 3  how fast is at&t internet
# 4                     at&t #
# 6               at&t student
# 7               at&tinternet
#
#                                                  URL  \
# 0  https://www.att.com/internet/fiber/att-vs-spec...
# 3  https://www.att.com/internet/internet-service-...
# 4                      https://www.att.com/internet/
# 6             https://www.att.com/internet/students/
# 7                      https://www.att.com/internet/
#
#    Impressions Aug 2024 - Aug 2024  Impressions Aug 2025 - Aug 2025  \
# 0                              190                              222
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The DataFrame was successfully filtered to include only rows where the 'URL' column starts with 'https://www.att.com/internet/'.
# *   A second filter was applied using a regular expression pattern on the 'Keyword' column, retaining rows where the keyword matches the specified branded pattern.
#
# ### Insights or Next Steps
#
# *   The filtering process effectively isolated branded keywords associated with 'att.com/internet' URLs, which is crucial for analyzing branded search performance on this specific section of the website.
# *   The resulting filtered DataFrame can now be used for further analysis, such as examining branded keyword performance metrics (e.g., clicks, impressions, CTR, average position) specifically for the internet section of the website.

# %% [markdown]
# # Task
# Analyze the provided Google Search Console data for branded keywords on the `/internet/` URLs, comparing the performance between August 2024 and August 2025 from an SEO perspective. Identify key trends, top-performing keywords, and keywords with significant changes in metrics like Impressions, Clicks, CTR, and Average Position. Present the findings with relevant visualizations and a summary of SEO insights.

# %% [markdown]
# ## Analyze overall seo metrics
#
# ### Subtask:
# Calculate and compare key SEO metrics (Impressions, Clicks, CTR, and Average Position) for 2024 and 2025 for the filtered data (branded keywords on the `/internet/` URLs).

# %% [markdown]
# **Reasoning**:
# Calculate the sum of Impressions and Clicks for both years from the filtered DataFrame and calculate the average of CTR and Average Position for both years, handling non-numeric values, then display the calculated metrics.

# %%
import numpy as np

# Calculate total impressions
total_impressions_2024 = df_filtered_regex['Impressions Aug 2024 - Aug 2024'].sum()
total_impressions_2025 = df_filtered_regex['Impressions Aug 2025 - Aug 2025'].sum()

# Calculate total clicks
total_clicks_2024 = df_filtered_regex['Clicks Aug 2024 - Aug 2024'].sum()
total_clicks_2025 = df_filtered_regex['Clicks Aug 2025 - Aug 2025'].sum()

# Convert CTR columns to numeric, coercing errors to NaN
df_filtered_regex['CTR Aug 2024 - Aug 2024'] = pd.to_numeric(df_filtered_regex['CTR Aug 2024 - Aug 2024'], errors='coerce')
df_filtered_regex['CTR Aug 2025 - Aug 2025'] = pd.to_numeric(df_filtered_regex['CTR Aug 2025 - Aug 2025'], errors='coerce')

# Calculate average CTR, ignoring NaN values
average_ctr_2024 = df_filtered_regex['CTR Aug 2024 - Aug 2024'].mean()
average_ctr_2025 = df_filtered_regex['CTR Aug 2025 - Aug 2025'].mean()

# Convert Average Position columns to numeric, coercing errors to NaN
df_filtered_regex['Average Position Aug 2024 - Aug 2024'] = pd.to_numeric(df_filtered_regex['Average Position Aug 2024 - Aug 2024'], errors='coerce')
df_filtered_regex['Average Position Aug 2025 - Aug 2025'] = pd.to_numeric(df_filtered_regex['Average Position Aug 2025 - Aug 2025'], errors='coerce')

# Calculate average Average Position, ignoring NaN values
average_position_2024 = df_filtered_regex['Average Position Aug 2024 - Aug 2024'].replace(0, np.nan).mean()
average_position_2025 = df_filtered_regex['Average Position Aug 2025 - Aug 2025'].replace(0, np.nan).mean()


# Display the calculated metrics
print("Overall SEO Metrics for Branded Keywords on /internet/ URLs:")
print("-" * 50)
print(f"Total Impressions (Aug 2024): {total_impressions_2024}")
print(f"Total Impressions (Aug 2025): {total_impressions_2025}")
print("-" * 50)
print(f"Total Clicks (Aug 2024): {total_clicks_2024}")
print(f"Total Clicks (Aug 2025): {total_clicks_2025}")
print("-" * 50)
print(f"Average CTR (Aug 2024): {average_ctr_2024:.4f}")
print(f"Average CTR (Aug 2025): {average_ctr_2025:.4f}")
print("-" * 50)
print(f"Average Position (Aug 2024): {average_position_2024:.2f}")
print(f"Average Position (Aug 2025): {average_position_2025:.2f}")
# Out:
# Overall SEO Metrics for Branded Keywords on /internet/ URLs:
# --------------------------------------------------
# Total Impressions (Aug 2024): 11172837
# Total Impressions (Aug 2025): 10312878
# --------------------------------------------------
# Total Clicks (Aug 2024): 395625
# Total Clicks (Aug 2025): 347346
# --------------------------------------------------
# Average CTR (Aug 2024): 0.2497
# Average CTR (Aug 2025): 0.2971
# --------------------------------------------------
# Average Position (Aug 2024): 2.67
# Average Position (Aug 2025): 2.79
# /tmp/ipython-input-2305209850.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# ## Analyze changes in seo metrics
#
# ### Subtask:
# Calculate the absolute and percentage change for each SEO metric between 2024 and 2025.

# %% [markdown]
# **Reasoning**:
# Calculate the absolute and percentage changes for each SEO metric between 2024 and 2025 and print the results.

# %%
# Calculate absolute and percentage changes for Impressions
impressions_absolute_change = total_impressions_2025 - total_impressions_2024
impressions_percentage_change = (impressions_absolute_change / total_impressions_2024) * 100 if total_impressions_2024 != 0 else 0

# Calculate absolute and percentage changes for Clicks
clicks_absolute_change = total_clicks_2025 - total_clicks_2024
clicks_percentage_change = (clicks_absolute_change / total_clicks_2024) * 100 if total_clicks_2024 != 0 else 0

# Calculate absolute and percentage changes for CTR
ctr_absolute_change = average_ctr_2025 - average_ctr_2024
ctr_percentage_change = (ctr_absolute_change / average_ctr_2024) * 100 if average_ctr_2024 != 0 else 0

# Calculate absolute and percentage changes for Average Position
average_position_absolute_change = average_position_2025 - average_position_2024
average_position_percentage_change = (average_position_absolute_change / average_position_2024) * 100 if average_position_2024 != 0 else 0

# Print the calculated changes
print("\nSEO Metric Changes (Aug 2024 vs Aug 2025):")
print("-" * 50)
print(f"Impressions Absolute Change: {impressions_absolute_change}")
print(f"Impressions Percentage Change: {impressions_percentage_change:.2f}%")
print("-" * 50)
print(f"Clicks Absolute Change: {clicks_absolute_change}")
print(f"Clicks Percentage Change: {clicks_percentage_change:.2f}%")
print("-" * 50)
print(f"Average CTR Absolute Change: {ctr_absolute_change:.4f}")
print(f"Average CTR Percentage Change: {ctr_percentage_change:.2f}%")
print("-" * 50)
print(f"Average Position Absolute Change: {average_position_absolute_change:.2f}")
print(f"Average Position Percentage Change: {average_position_percentage_change:.2f}%")
# Out:
# SEO Metric Changes (Aug 2024 vs Aug 2025):
# --------------------------------------------------
# Impressions Absolute Change: -859959
# Impressions Percentage Change: -7.70%
# --------------------------------------------------
# Clicks Absolute Change: -48279
# Clicks Percentage Change: -12.20%
# --------------------------------------------------
# Average CTR Absolute Change: 0.0474
# Average CTR Percentage Change: 19.00%
# --------------------------------------------------
# Average Position Absolute Change: 0.12
# Average Position Percentage Change: 4.62%

# %% [markdown]
# ## Identify top performing keywords
#
# ### Subtask:
# Find the top keywords based on metrics like Impressions or Clicks in both 2024 and 2025.

# %% [markdown]
# **Reasoning**:
# Sort the DataFrame by Impressions and Clicks for both years and display the top 10 keywords for each.

# %%
print("Top 10 Keywords by Impressions in Aug 2024:")
display(df_filtered_regex.sort_values(by='Impressions Aug 2024 - Aug 2024', ascending=False).head(10)[['Keyword', 'Impressions Aug 2024 - Aug 2024']])

print("\nTop 10 Keywords by Impressions in Aug 2025:")
display(df_filtered_regex.sort_values(by='Impressions Aug 2025 - Aug 2025', ascending=False).head(10)[['Keyword', 'Impressions Aug 2025 - Aug 2025']])

print("\nTop 10 Keywords by Clicks in Aug 2024:")
display(df_filtered_regex.sort_values(by='Clicks Aug 2024 - Aug 2024', ascending=False).head(10)[['Keyword', 'Clicks Aug 2024 - Aug 2024']])

print("\nTop 10 Keywords by Clicks in Aug 2025:")
display(df_filtered_regex.sort_values(by='Clicks Aug 2025 - Aug 2025', ascending=False).head(10)[['Keyword', 'Clicks Aug 2025 - Aug 2025']])
# Out:
# Top 10 Keywords by Impressions in Aug 2024:
#              Keyword  Impressions Aug 2024 - Aug 2024
# 6560             att                          3430539
# 3506            at&t                          1239679
# 9340               t                           383661
# 8298    att internet                           289613
# 1112    att internet                           271983
# 5489    att internet                           271694
# 9091    att internet                           252476
# 3237   at&t internet                           208452
# 6620       att fiber                           206923
# 12780  at&t internet                           204612
# Top 10 Keywords by Impressions in Aug 2025:
#              Keyword  Impressions Aug 2025 - Aug 2025
# 6560             att                          2348827
# 3506            at&t                          1377853
# 9340               t                           534445
# 6023            at&t                           281416
# ...

# %% [markdown]
# ## Analyze keywords with significant changes
#
# ### Subtask:
# Identify keywords that show significant positive or negative changes in key metrics between 2024 and 2025.

# %% [markdown]
# **Reasoning**:
# Calculate the absolute and percentage change for Impressions, Clicks, CTR, and Average Position for each keyword and then identify keywords with significant changes based on percentage changes, considering a minimum threshold for initial values.

# %%
# Calculate absolute and percentage changes for each keyword
df_filtered_regex['Impressions Absolute Change'] = df_filtered_regex['Impressions Aug 2025 - Aug 2025'] - df_filtered_regex['Impressions Aug 2024 - Aug 2024']
df_filtered_regex['Impressions Percentage Change'] = (df_filtered_regex['Impressions Absolute Change'] / df_filtered_regex['Impressions Aug 2024 - Aug 2024']) * 100

df_filtered_regex['Clicks Absolute Change'] = df_filtered_regex['Clicks Aug 2025 - Aug 2025'] - df_filtered_regex['Clicks Aug 2024 - Aug 2024']
df_filtered_regex['Clicks Percentage Change'] = (df_filtered_regex['Clicks Absolute Change'] / df_filtered_regex['Clicks Aug 2024 - Aug 2024']) * 100

# Convert CTR columns to numeric, coercing errors to NaN
df_filtered_regex['CTR Aug 2024 - Aug 2024'] = pd.to_numeric(df_filtered_regex['CTR Aug 2024 - Aug 2024'], errors='coerce')
df_filtered_regex['CTR Aug 2025 - Aug 2025'] = pd.to_numeric(df_filtered_regex['CTR Aug 2025 - Aug 2025'], errors='coerce')

df_filtered_regex['CTR Absolute Change'] = df_filtered_regex['CTR Aug 2025 - Aug 2025'] - df_filtered_regex['CTR Aug 2024 - Aug 2024']
df_filtered_regex['CTR Percentage Change'] = (df_filtered_regex['CTR Absolute Change'] / df_filtered_regex['CTR Aug 2024 - Aug 2024']) * 100

# Convert Average Position columns to numeric, coercing errors to NaN
df_filtered_regex['Average Position Aug 2024 - Aug 2024'] = pd.to_numeric(df_filtered_regex['Average Position Aug 2024 - Aug 2024'], errors='coerce').replace(0, np.nan)
df_filtered_regex['Average Position Aug 2025 - Aug 2025'] = pd.to_numeric(df_filtered_regex['Average Position Aug 2025 - Aug 2025'], errors='coerce').replace(0, np.nan)

df_filtered_regex['Average Position Absolute Change'] = df_filtered_regex['Average Position Aug 2025 - Aug 2025'] - df_filtered_regex['Average Position Aug 2024 - Aug 2024']
df_filtered_regex['Average Position Percentage Change'] = (df_filtered_regex['Average Position Absolute Change'] / df_filtered_regex['Average Position Aug 2024 - Aug 2024']) * 100

# Set a minimum threshold for initial metric values
min_impressions = 100
min_clicks = 10
min_ctr = 0.01
min_avg_position = 1

# Identify keywords with significant positive/negative changes
print("Top 10 Keywords with Significant Positive Impressions Change (>= {} initial impressions):".format(min_impressions))
display(df_filtered_regex[df_filtered_regex['Impressions Aug 2024 - Aug 2024'] >= min_impressions].sort_values(by='Impressions Percentage Change', ascending=False).head(10)[['Keyword', 'Impressions Aug 2024 - Aug 2024', 'Impressions Aug 2025 - Aug 2025', 'Impressions Absolute Change', 'Impressions Percentage Change']])

print("\nTop 10 Keywords with Significant Negative Impressions Change (>= {} initial impressions):".format(min_impressions))
display(df_filtered_regex[df_filtered_regex['Impressions Aug 2024 - Aug 2024'] >= min_impressions].sort_values(by='Impressions Percentage Change', ascending=True).head(10)[['Keyword', 'Impressions Aug 2024 - Aug 2024', 'Impressions Aug 2025 - Aug 2025', 'Impressions Absolute Change', 'Impressions Percentage Change']])

print("\nTop 10 Keywords with Significant Positive Clicks Change (>= {} initial clicks):".format(min_clicks))
display(df_filtered_regex[df_filtered_regex['Clicks Aug 2024 - Aug 2024'] >= min_clicks].sort_values(by='Clicks Percentage Change', ascending=False).head(10)[['Keyword', 'Clicks Aug 2024 - Aug 2024', 'Clicks Aug 2025 - Aug 2025', 'Clicks Absolute Change', 'Clicks Percentage Change']])

print("\nTop 10 Keywords with Significant Negative Clicks Change (>= {} initial clicks):".format(min_clicks))
display(df_filtered_regex[df_filtered_regex['Clicks Aug 2024 - Aug 2024'] >= min_clicks].sort_values(by='Clicks Percentage Change', ascending=True).head(10)[['Keyword', 'Clicks Aug 2024 - Aug 2024', 'Clicks Aug 2025 - Aug 2025', 'Clicks Absolute Change', 'Clicks Percentage Change']])

print("\nTop 10 Keywords with Significant Positive CTR Change (>= {} initial CTR):".format(min_ctr))
display(df_filtered_regex[df_filtered_regex['CTR Aug 2024 - Aug 2024'] >= min_ctr].sort_values(by='CTR Percentage Change', ascending=False).head(10)[['Keyword', 'CTR Aug 2024 - Aug 2024', 'CTR Aug 2025 - Aug 2025', 'CTR Absolute Change', 'CTR Percentage Change']])

print("\nTop 10 Keywords with Significant Negative CTR Change (>= {} initial CTR):".format(min_ctr))
display(df_filtered_regex[df_filtered_regex['CTR Aug 2024 - Aug 2024'] >= min_ctr].sort_values(by='CTR Percentage Change', ascending=True).head(10)[['Keyword', 'CTR Aug 2024 - Aug 2024', 'CTR Aug 2025 - Aug 2025', 'CTR Absolute Change', 'CTR Percentage Change']])

print("\nTop 10 Keywords with Significant Positive Average Position Change (Worse Ranking, >= {} initial Avg Pos):".format(min_avg_position))
display(df_filtered_regex[df_filtered_regex['Average Position Aug 2024 - Aug 2024'] >= min_avg_position].sort_values(by='Average Position Percentage Change', ascending=False).head(10)[['Keyword', 'Average Position Aug 2024 - Aug 2024', 'Average Position Aug 2025 - Aug 2025', 'Average Position Absolute Change', 'Average Position Percentage Change']])

print("\nTop 10 Keywords with Significant Negative Average Position Change (Better Ranking, >= {} initial Avg Pos):".format(min_avg_position))
display(df_filtered_regex[df_filtered_regex['Average Position Aug 2024 - Aug 2024'] >= min_avg_position].sort_values(by='Average Position Percentage Change', ascending=True).head(10)[['Keyword', 'Average Position Aug 2024 - Aug 2024', 'Average Position Aug 2025 - Aug 2025', 'Average Position Absolute Change', 'Average Position Percentage Change']])
# Out:
# Top 10 Keywords with Significant Positive Impressions Change (>= 100 initial impressions):
# /tmp/ipython-input-725697019.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered_regex['Impressions Absolute Change'] = df_filtered_regex['Impressions Aug 2025 - Aug 2025'] - df_filtered_regex['Impressions Aug 2024 - Aug 2024']
# /tmp/ipython-input-725697019.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# ## Visualize key trends
#
# ### Subtask:
# Create visualizations (e.g., bar charts or line plots) to show the comparison of key SEO metrics between 2024 and 2025.

# %% [markdown]
# **Reasoning**:
# Create bar plots to visualize the comparison of key SEO metrics between 2024 and 2025.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Metrics and their values for 2024 and 2025
metrics = ['Impressions', 'Clicks', 'CTR', 'Average Position']
values_2024 = [total_impressions_2024, total_clicks_2024, average_ctr_2024, average_position_2024]
values_2025 = [total_impressions_2025, total_clicks_2025, average_ctr_2025, average_position_2025]

# Create bar plot for Impressions
plt.figure(figsize=(8, 5))
sns.barplot(x=['Aug 2024', 'Aug 2025'], y=[values_2024[0], values_2025[0]])
plt.ylabel('Total Impressions')
plt.title('Comparison of Total Impressions (Aug 2024 vs Aug 2025)')
plt.show()

# Create bar plot for Clicks
plt.figure(figsize=(8, 5))
sns.barplot(x=['Aug 2024', 'Aug 2025'], y=[values_2024[1], values_2025[1]])
plt.ylabel('Total Clicks')
plt.title('Comparison of Total Clicks (Aug 2024 vs Aug 2025)')
plt.show()

# Create bar plot for CTR
plt.figure(figsize=(8, 5))
sns.barplot(x=['Aug 2024', 'Aug 2025'], y=[values_2024[2], values_2025[2]])
plt.ylabel('Average CTR')
plt.title('Comparison of Average CTR (Aug 2024 vs Aug 2025)')
plt.show()

# Create bar plot for Average Position
plt.figure(figsize=(8, 5))
sns.barplot(x=['Aug 2024', 'Aug 2025'], y=[values_2024[3], values_2025[3]])
plt.ylabel('Average Position (Lower is Better)')
plt.title('Comparison of Average Position (Aug 2024 vs Aug 2025)')
plt.show()

# %% [markdown]
# ## Summarize seo insights
#
# ### Subtask:
# Provide a summary of the key findings from the analysis, highlighting significant changes and insights from an SEO point of view.

# %% [markdown]
# **Reasoning**:
# Synthesize the findings from the previous steps to create a comprehensive summary of the key SEO insights.

# %%
print("## SEO Analysis Summary for Branded Keywords on /internet/ URLs (Aug 2024 vs Aug 2025)")
print("\n**Overall Performance:**")
print(f"- Total Impressions decreased by {impressions_percentage_change:.2f}% ({impressions_absolute_change:,.0f} fewer impressions) year-over-year.")
print(f"- Total Clicks also decreased by {clicks_percentage_change:.2f}% ({clicks_absolute_change:,.0f} fewer clicks) year-over-year.")
print(f"- Average CTR significantly increased by {ctr_percentage_change:.2f}% (+{ctr_absolute_change:.4f}) year-over-year.")
print(f"- Average Position slightly worsened by {average_position_percentage_change:.2f}% (+{average_position_absolute_change:.2f}) year-over-year.")

print("\n**Interpretation:**")
print("The decrease in impressions and clicks suggests either reduced search demand for branded 'internet' keywords, increased competition, or potential algorithm shifts impacting visibility. However, the notable increase in CTR indicates that when users *do* see the results for these branded keywords, they are more likely to click. This could be due to improved snippet optimization, more compelling messaging, or a stronger brand association for users who are searching.")
print("The slight decline in average position suggests that on average, branded internet keywords are ranking slightly lower in 2025 compared to 2024. This could be a contributing factor to the decrease in impressions and clicks.")

print("\n**Top Performing Keywords:**")
print("The top performing keywords in both years highlight the importance of core branded terms like 'att internet' and 'att fiber'. Shifts in the top keywords for clicks (from 'att internet' in 2024 to 'att fiber' in 2025) might indicate changing user interest or promotional focus towards fiber services.")

print("\n**Keywords with Significant Changes:**")
print("Analyzing keywords with significant changes revealed specific opportunities and areas of concern. Keywords with large positive changes in impressions or clicks could be growing in search volume or benefiting from improved relevance and ranking. Conversely, keywords with significant negative changes require further investigation to understand the root causes, which could range from technical issues to content decay or increased competitor activity.")
print("Keywords with significant positive CTR changes, even with decreasing impressions, are effectively capturing user attention when they appear. Identifying what makes these snippets compelling could inform optimization strategies for other keywords.")
print("Keywords with significant positive average position changes (worse ranking) are clear candidates for SEO efforts to improve their search visibility and recover lost impressions and clicks.")

print("\n**SEO Recommendations:**")
print("- Investigate the reasons behind the overall decrease in branded impressions and clicks. This could involve analyzing search trend data, competitor activity, and recent website or algorithm changes.")
print("- Leverage the insights from keywords with high and improving CTRs to optimize meta descriptions and titles for other branded internet terms.")
print("- Prioritize improving the average position for keywords that have seen a significant decline in ranking, as this directly impacts visibility and traffic.")
print("- Monitor the performance of top keywords closely and adapt strategies based on changing user search behavior, particularly the apparent increased interest in 'att fiber'.")
# Out:
# ## SEO Analysis Summary for Branded Keywords on /internet/ URLs (Aug 2024 vs Aug 2025)
#
# **Overall Performance:**
# - Total Impressions decreased by -7.70% (-859,959 fewer impressions) year-over-year.
# - Total Clicks also decreased by -12.20% (-48,279 fewer clicks) year-over-year.
# - Average CTR significantly increased by 19.00% (+0.0474) year-over-year.
# - Average Position slightly worsened by 4.62% (+0.12) year-over-year.
#
# **Interpretation:**
# The decrease in impressions and clicks suggests either reduced search demand for branded 'internet' keywords, increased competition, or potential algorithm shifts impacting visibility. However, the notable increase in CTR indicates that when users *do* see the results for these branded keywords, they are more likely to click. This could be due to improved snippet optimization, more compelling messaging, or a stronger brand association for users who are searching.
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   Total Impressions for branded keywords on `/internet/` URLs decreased by 7.70% from 11,172,837 in August 2024 to 10,312,878 in August 2025.
# *   Total Clicks for these keywords also decreased by 12.20% from 395,625 in August 2024 to 347,346 in August 2025.
# *   Average CTR saw a significant increase of 19.00%, rising from 0.2497 in August 2024 to 0.2971 in August 2025.
# *   The Average Position slightly worsened by 4.62%, moving from 2.67 in August 2024 to 2.79 in August 2025.
# *   The keyword "att" had the highest impressions in both August 2024 and August 2025.
# *   "att internet" had the highest clicks in August 2024, while "att fiber" had the highest clicks in August 2025.
#
# ### Insights or Next Steps
#
# *   Investigate the reasons behind the overall decrease in branded impressions and clicks, considering factors like search trend data, competitor activity, and recent site changes.
# *   Analyze keywords with significant positive CTR changes to identify successful snippet strategies and apply them to other branded internet terms.
